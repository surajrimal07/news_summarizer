# %%
#importing libraries
import math
import re
from nltk.corpus import stopwords
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import os

# with open("../input/nepali-dataset/corona.txt","r") as f:
#     text = f.read()
#     print(text)
text = "शेयरबजार र घरजग्गामा बैंकहरुको कर्जा लगानी तीब्र गतिमा बढ्न थालेको देखिएको छ। राष्ट्र बैंकको कडाइले गर्दा केही घटेको कर्जा लगानी पछिल्लो केही महिना यता पुनः बढ्न थालेको हो। राष्ट्र बैंकको तथ्याँक अनुसार गत ११ महिनामा रियल स्टेट क्षेत्रको कर्जा ४.५० प्रतिशतले बढेको छ त्यसमा पनि जग्गा खरिद र प्लटिङको लागि दिइने कर्जा १०.४ प्रतिशतले बढेको छ। यता शेयर बजारको कर्जा समेत १४.२ प्रतिशतले बढेको छ। शेयर बजारमा जाने कर्जामा १ करोडमाथिको कर्जा सबैभन्दा धेरै २०.४ प्रतिशतले बढेको राष्ट्र बैंकले जनाएको छ। यस अवधिमा बैंकको कुल कर्जा भने ५.२ प्रतिशतले बढेको छ। बैंकको कुल कर्जामा जग्गा खरिद र शेयर खरिदको लागि जाने कर्जा सबैभन्दा धेरै रहेको देखिन्छ। गत आर्थिक वर्षको अन्तिमसम्ममा बैंक तथा वित्तीय संस्थाले कुल ४८ खर्ब ७९ अर्ब रुपैयाँ कर्जा दिएका थिए। गत जेठसम्ममा यी कर्जा बढेर ५१ खर्ब ३४ अर्ब रुपैयाँ पुगेको छ। जुन ५.२ प्रतिशतको बृद्धि हो। यस अवधिमा बैंक तथा वित्तीय संस्थाले २ खर्ब ५५ अर्ब रुपैयाँ कर्जा दिएका छन्। राष्ट्र बैंकले साढे ११ प्रतिशतको कर्जा बृद्धिको लक्ष्य राखे पनि बैंकहरुको कर्जाको बृद्धिदर निकै कम छ। शेयर बजारको कर्जा हेर्दा अन्य क्षेत्रको तुलनामा धेरै बढेको देखिन्छ। समग्र बैंकको कर्जाभन्दा यस क्षेत्रको कर्जा धेरै बढेको छ। अघिल्लाे आर्थिक वर्षको असार मशान्तसम्ममा ७६ अर्ब ३० करोड रुपैयाँ रहेको शेयर धितो कर्जा गत जेठसम्म्मा बढेर ८७ अर्ब ११ करोड रुपैयाँ पुगेको छ। जुन १० अर्ब रुपैयाँको बृद्धि हो। यस्तै रियल स्टेट क्षेत्रको कर्जा हेर्दा पछिल्लो वर्षदेखि नै बढ्दो क्रममा छ। गत वर्ष समग्र रियल स्टेट क्षेत्रको कर्जा १० अर्ब ७३ करोड अर्थात ४.३ प्रतिशतले बढेको छ। अघिल्लो आर्थिक वर्षको असारसम्ममा २ खर्ब ४९ करोड रुपैयाँ रहेको यस्तो कर्जा बढेर २ खर्ब ६० अर्ब रुपैयाँ पुगेको छ। रियल स्टेट क्षेत्रमा पनि जग्गा खरिद र प्लटिङको लागि जाने कर्जाको बृद्धिदर सबैभन्दा धेरै देखिन्छ। अघिल्लो वर्षको असारसम्ममा जग्गा खरिद र प्लटिङको लागि ४५ अर्ब ३३ करोड रुपैयाँ कर्जा दिएका बैंकहरुले गत जेठसम्ममा ५० अर्ब ३ करोड कर्जा दिएका छन्। गत ११ महिनामा बैंकहरुले ४ अर्ब ६९ करोड रुपैयाँ कर्जा दिएका छन्।"

# %%
len(text)
# Out:
# 1885

# %%
sents=re.split('।',text)

# %%
print(sents)
# Out:
# ['शेयरबजार र घरजग्गामा बैंकहरुको कर्जा लगानी तीब्र गतिमा बढ्न थालेको देखिएको छ', ' राष्ट्र बैंकको कडाइले गर्दा केही घटेको कर्जा लगानी पछिल्लो केही महिना यता पुनः बढ्न थालेको हो', ' राष्ट्र बैंकको तथ्याँक अनुसार गत ११ महिनामा रियल स्टेट क्षेत्रको कर्जा ४.५० प्रतिशतले बढेको छ त्यसमा पनि जग्गा खरिद र प्लटिङको लागि दिइने कर्जा १०.४ प्रतिशतले बढेको छ', ' यता शेयर बजारको कर्जा समेत १४.२ प्रतिशतले बढेको छ', ' शेयर बजारमा जाने कर्जामा १ करोडमाथिको कर्जा सबैभन्दा धेरै २०.४ प्रतिशतले बढेको राष्ट्र बैंकले जनाएको छ', ' यस अवधिमा बैंकको कुल कर्जा भने ५.२ प्रतिशतले बढेको छ', ' बैंकको कुल कर्जामा जग्गा खरिद र शेयर खरिदको लागि जाने कर्जा सबैभन्दा धेरै रहेको देखिन्छ', ' गत आर्थिक वर्षको अन्तिमसम्ममा बैंक तथा वित्तीय संस्थाले कुल ४८ खर्ब ७९ अर्ब रुपैयाँ कर्जा दिएका थिए', ' गत जेठसम्ममा यी कर्जा बढेर ५१ खर्ब ३४ अर्ब रुपैयाँ पुगेको छ', ' जुन ५.२ प्रतिशतको बृद्धि हो', ' यस अवधिमा बैंक तथा वित्तीय संस्थाले २ खर्ब ५५ अर्ब रुपैयाँ कर्जा दिएका छन्', ' राष्ट्र बैंकले साढे ११ प्रतिशतको कर्जा बृद्धिको लक्ष्य रा
# ...

# %%
documents_size = len(sents)
print(documents_size)
# Out:
# 23

# %%
words=text.split()
print(words)
# Out:
# ['शेयरबजार', 'र', 'घरजग्गामा', 'बैंकहरुको', 'कर्जा', 'लगानी', 'तीब्र', 'गतिमा', 'बढ्न', 'थालेको', 'देखिएको', 'छ।', 'राष्ट्र', 'बैंकको', 'कडाइले', 'गर्दा', 'केही', 'घटेको', 'कर्जा', 'लगानी', 'पछिल्लो', 'केही', 'महिना', 'यता', 'पुनः', 'बढ्न', 'थालेको', 'हो।', 'राष्ट्र', 'बैंकको', 'तथ्याँक', 'अनुसार', 'गत', '११', 'महिनामा', 'रियल', 'स्टेट', 'क्षेत्रको', 'कर्जा', '४.५०', 'प्रतिशतले', 'बढेको', 'छ', 'त्यसमा', 'पनि', 'जग्गा', 'खरिद', 'र', 'प्लटिङको', 'लागि', 'दिइने', 'कर्जा', '१०.४', 'प्रतिशतले', 'बढेको', 'छ।', 'यता', 'शेयर', 'बजारको', 'कर्जा', 'समेत', '१४.२', 'प्रतिशतले', 'बढेको', 'छ।', 'शेयर', 'बजारमा', 'जाने', 'कर्जामा', '१', 'करोडमाथिको', 'कर्जा', 'सबैभन्दा', 'धेरै', '२०.४', 'प्रतिशतले', 'बढेको', 'राष्ट्र', 'बैंकले', 'जनाएको', 'छ।', 'यस', 'अवधिमा', 'बैंकको', 'कुल', 'कर्जा', 'भने', '५.२', 'प्रतिशतले', 'बढेको', 'छ।', 'बैंकको', 'कुल', 'कर्जामा', 'जग्गा', 'खरिद', 'र', 'शेयर', 'खरिदको', 'लागि', 'जाने', 'कर्जा', 'सबैभन्दा', 'धेरै', 'रहेको', 'देखिन्छ।', 'गत', 'आर्थिक', 'वर्षको', 'अन्तिमसम्ममा'
# ...

# %%
def create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("nepali"))

    for sent in sentences:
        freq_table = {}
        words=sent.split()
        for word in words:
            if word in stopWords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:10]] = freq_table

    return frequency_matrix

# %%
freq_matrix = create_frequency_matrix(sents)

# %%
freq_matrix
# Out:
# {'शेयरबजार र': {'शेयरबजार': 1,
#   'घरजग्गामा': 1,
#   'बैंकहरुको': 1,
#   'कर्जा': 1,
#   'लगानी': 1,
#   'तीब्र': 1,
#   'गतिमा': 1,
#   'बढ्न': 1,
#   'थालेको': 1,
#   'देखिएको': 1},
#  ' राष्ट्र ब': {'राष्ट्र': 1,
#   'बैंकले': 1,
#   'साढे': 1,
#   '११': 1,
#   'प्रतिशतको': 1,
#   'कर्जा': 1,
#   'बृद्धिको': 1,
#   'लक्ष्य': 1,
#   'बैंकहरुको': 1,
#   'कर्जाको': 1,
#   'बृद्धिदर': 1,
#   'निकै': 1,
#   'कम': 1},
#  ' यता शेयर ': {'यता': 1,
#   'शेयर': 1,
#   'बजारको': 1,
#   'कर्जा': 1,
#   'समेत': 1,
#   '१४.२': 1,
#   'प्रतिशतले': 1,
#   'बढेको': 1},
#  ' शेयर बजार': {'शेयर': 1,
#   'बजारको': 1,
#   'कर्जा': 1,
#   'हेर्दा': 1,
#   'क्षेत्रको': 1,
#   'तुलनामा': 1,
#   'बढेको': 1},
#  ' यस अवधिमा': {'अवधिमा': 1,
#   'बैंक': 1,
#   'वित्तीय': 1,
#   'संस्थाले': 1,
#   '२': 1,
#   'खर्ब': 1,
#   '५५': 1,
#   'अर्ब': 1,
#   'रुपैयाँ': 1,
#   'कर्जा': 1,
#   'दिएका': 1},
#  ' बैंकको कु': {'बैंकको': 1,
#   'कुल': 1,
#   'कर्जामा': 1,
#   'जग्गा': 1,
#   'खरिद': 1,
#   'शेयर': 1,
# ...

# %%
def create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix

# %%
tf_matrix = create_tf_matrix(freq_matrix)

# %%
tf_matrix
# Out:
# {'शेयरबजार र': {'शेयरबजार': 0.1,
#   'घरजग्गामा': 0.1,
#   'बैंकहरुको': 0.1,
#   'कर्जा': 0.1,
#   'लगानी': 0.1,
#   'तीब्र': 0.1,
#   'गतिमा': 0.1,
#   'बढ्न': 0.1,
#   'थालेको': 0.1,
#   'देखिएको': 0.1},
#  ' राष्ट्र ब': {'राष्ट्र': 0.07692307692307693,
#   'बैंकले': 0.07692307692307693,
#   'साढे': 0.07692307692307693,
#   '११': 0.07692307692307693,
#   'प्रतिशतको': 0.07692307692307693,
#   'कर्जा': 0.07692307692307693,
#   'बृद्धिको': 0.07692307692307693,
#   'लक्ष्य': 0.07692307692307693,
#   'बैंकहरुको': 0.07692307692307693,
#   'कर्जाको': 0.07692307692307693,
#   'बृद्धिदर': 0.07692307692307693,
#   'निकै': 0.07692307692307693,
#   'कम': 0.07692307692307693},
#  ' यता शेयर ': {'यता': 0.125,
#   'शेयर': 0.125,
#   'बजारको': 0.125,
#   'कर्जा': 0.125,
#   'समेत': 0.125,
#   '१४.२': 0.125,
#   'प्रतिशतले': 0.125,
#   'बढेको': 0.125},
#  ' शेयर बजार': {'शेयर': 0.14285714285714285,
#   'बजारको': 0.14285714285714285,
#   'कर्जा': 0.14285714285714285,
# ...

# %%
def create_idf_matrix(freq_matrix, count_doc_per_words, documents_size):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(documents_size / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix

# %%
def create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table

# %%
count_doc_per_words = create_documents_per_words(freq_matrix)

# %%
idf_matrix = create_idf_matrix(freq_matrix,count_doc_per_words, documents_size)

# %%
idf_matrix
# Out:
# {'शेयरबजार र': {'शेयरबजार': 1.3617278360175928,
#   'घरजग्गामा': 1.3617278360175928,
#   'बैंकहरुको': 1.0606978403536116,
#   'कर्जा': 0.18563657696191166,
#   'लगानी': 1.3617278360175928,
#   'तीब्र': 1.3617278360175928,
#   'गतिमा': 1.3617278360175928,
#   'बढ्न': 1.3617278360175928,
#   'थालेको': 1.3617278360175928,
#   'देखिएको': 1.3617278360175928},
#  ' राष्ट्र ब': {'राष्ट्र': 1.3617278360175928,
#   'बैंकले': 1.3617278360175928,
#   'साढे': 1.3617278360175928,
#   '११': 0.8846065812979305,
#   'प्रतिशतको': 1.0606978403536116,
#   'कर्जा': 0.18563657696191166,
#   'बृद्धिको': 1.3617278360175928,
#   'लक्ष्य': 1.3617278360175928,
#   'बैंकहरुको': 1.0606978403536116,
#   'कर्जाको': 1.0606978403536116,
#   'बृद्धिदर': 1.0606978403536116,
#   'निकै': 1.3617278360175928,
#   'कम': 1.3617278360175928},
#  ' यता शेयर ': {'यता': 1.3617278360175928,
#   'शेयर': 0.7596678446896304,
#   'बजारको': 1.0606978403536116,
#   'कर्जा': 0.18563657696191166,
#   'समेत': 1.3617278360175928,
# ...

# %%
def create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(),
                                                    f_table2.items()):
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix

# %%
tf_idf_matrix = create_tf_idf_matrix(tf_matrix, idf_matrix)

# %%
tf_idf_matrix
# Out:
# {'शेयरबजार र': {'शेयरबजार': 0.1361727836017593,
#   'घरजग्गामा': 0.1361727836017593,
#   'बैंकहरुको': 0.10606978403536116,
#   'कर्जा': 0.018563657696191168,
#   'लगानी': 0.1361727836017593,
#   'तीब्र': 0.1361727836017593,
#   'गतिमा': 0.1361727836017593,
#   'बढ्न': 0.1361727836017593,
#   'थालेको': 0.1361727836017593,
#   'देखिएको': 0.1361727836017593},
#  ' राष्ट्र ब': {'राष्ट्र': 0.10474829507827638,
#   'बैंकले': 0.10474829507827638,
#   'साढे': 0.10474829507827638,
#   '११': 0.06804666009984081,
#   'प्रतिशतको': 0.08159214156566244,
#   'कर्जा': 0.01427973668937782,
#   'बृद्धिको': 0.10474829507827638,
#   'लक्ष्य': 0.10474829507827638,
#   'बैंकहरुको': 0.08159214156566244,
#   'कर्जाको': 0.08159214156566244,
#   'बृद्धिदर': 0.08159214156566244,
#   'निकै': 0.10474829507827638,
#   'कम': 0.10474829507827638},
#  ' यता शेयर ': {'यता': 0.1702159795021991,
#   'शेयर': 0.0949584805862038,
#   'बजारको': 0.13258723004420145,
#   'कर्जा': 0.023204572120238957,
# ...

# %%
def sentence_scores(tf_idf_matrix) -> dict:


    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0

        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence += score
        if count_words_in_sentence !=0:
            sentenceValue[sent] = total_score_per_sentence / count_words_in_sentence
        else:
            sentenceValue[sent]=0
    return sentenceValue

# %%
sentence_scores = sentence_scores(tf_idf_matrix)

# %%
print(sentence_scores)
# Out:
# {'शेयरबजार र': 0.12140157105456266, ' राष्ट्र ब': 0.08784100219998484, ' यता शेयर ': 0.12361799148595586, ' शेयर बजार': 0.12138293117868608, ' यस अवधिमा': 0.07930028448241659, ' बैंकको कु': 0.09680764617697037, ' गत आर्थिक': 0.058599614533384484, ' गत जेठसम्': 0.08006362804851755, ' जुन ५.२ प': 0.3870137240805351, ' समग्र बैं': 0.14411377175183301, ' अघिल्लाे ': 0.055109539539706216, ' जुन १० अर': 0.24316305270644278, ' यस्तै रिय': 0.1138534168971776, ' गत वर्ष स': 0.06324123572420633, ' अघिल्लो आ': 0.07238882468694255, ' रियल स्टे': 0.10203643362977373, ' अघिल्लो व': 0.05682278732896289, ' गत ११ महि': 0.0755887759607685, '': 0}

# %%
def find_average_score(sentenceValue) -> int:
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original summary_text
    average = (sumValues / len(sentenceValue))

    return average

# %%
threshold = find_average_score(sentence_scores)

# %%
threshold
# Out:
# 0.10959717007720142

# %%
def generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = []

    for sentence in sentences:
        if sentence[:10] in sentenceValue and sentenceValue[sentence[:10]] >= (threshold):
            summary.append(sentence)
            sentence_count += 1

    return summary

# %%
summary = '।'.join(generate_summary(sents, sentence_scores,0.8*threshold ))

# %%
print(summary)
# Out:
# शेयरबजार र घरजग्गामा बैंकहरुको कर्जा लगानी तीब्र गतिमा बढ्न थालेको देखिएको छ। राष्ट्र बैंकको कडाइले गर्दा केही घटेको कर्जा लगानी पछिल्लो केही महिना यता पुनः बढ्न थालेको हो। राष्ट्र बैंकको तथ्याँक अनुसार गत ११ महिनामा रियल स्टेट क्षेत्रको कर्जा ४.५० प्रतिशतले बढेको छ त्यसमा पनि जग्गा खरिद र प्लटिङको लागि दिइने कर्जा १०.४ प्रतिशतले बढेको छ। यता शेयर बजारको कर्जा समेत १४.२ प्रतिशतले बढेको छ। शेयर बजारमा जाने कर्जामा १ करोडमाथिको कर्जा सबैभन्दा धेरै २०.४ प्रतिशतले बढेको राष्ट्र बैंकले जनाएको छ। बैंकको कुल कर्जामा जग्गा खरिद र शेयर खरिदको लागि जाने कर्जा सबैभन्दा धेरै रहेको देखिन्छ। जुन ५.२ प्रतिशतको बृद्धि हो। राष्ट्र बैंकले साढे ११ प्रतिशतको कर्जा बृद्धिको लक्ष्य राखे पनि बैंकहरुको कर्जाको बृद्धिदर निकै कम छ। शेयर बजारको कर्जा हेर्दा अन्य क्षेत्रको तुलनामा धेरै बढेको देखिन्छ। समग्र बैंकको कर्जाभन्दा यस क्षेत्रको कर्जा धेरै बढेको छ। जुन १० अर्ब रुपैयाँको बृद्धि हो। यस्तै रियल स्टेट क्षेत्रको कर्जा हेर्दा पछिल्लो वर्षदेखि नै बढ्दो क्रममा छ। रियल स्टेट क्षेत्रमा पनि जग्गा खरिद र प्लटिङको ल
# ...

# %%
len(summary)
# Out:
# 1045
